# %% [markdown]
# #인공지능개론 4주차 과제
#
# ###컴퓨터공학과 202337644 김태규
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score, confusion_matrix
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

path = '/content/drive/MyDrive/Colab Notebooks/boston.csv'
df = pd.read_csv(path)
df
# Out:
#        Unnamed: 0  MedInc  HouseAge  AveRooms  AveBedrms  Population  \
# 0               0  8.3252      41.0  6.984127   1.023810       322.0
# 1               1  8.3014      21.0  6.238137   0.971880      2401.0
# 2               2  7.2574      52.0  8.288136   1.073446       496.0
# 3               3  5.6431      52.0  5.817352   1.073059       558.0
# 4               4  3.8462      52.0  6.281853   1.081081       565.0
# ...           ...     ...       ...       ...        ...         ...
# 20635       20635  1.5603      25.0  5.045455   1.133333       845.0
# 20636       20636  2.5568      18.0  6.114035   1.315789       356.0
# 20637       20637  1.7000      17.0  5.205543   1.120092      1007.0
# 20638       20638  1.8672      18.0  5.329513   1.171920       741.0
# 20639       20639  2.3886      16.0  5.254717   1.162264      1387.0
#
#        AveOccup  Latitude  Longitude  PRICE
# 0      2.555556     37.88    -122.23  4.526
# 1      2.109842     37.86    -122.22  3.585
# ...

# %%
X = df.drop(['PRICE'], axis=1)
X.head()
# Out:
#    Unnamed: 0  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0           0  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1           1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2           2  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3           3  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4           4  3.8462      52.0  6.281853   1.081081       565.0  2.181467
#
#    Latitude  Longitude
# 0     37.88    -122.23
# 1     37.86    -122.22
# 2     37.85    -122.24
# 3     37.85    -122.25
# 4     37.85    -122.25

# %%
y_reg = df['PRICE']
y.head()
# Out:
# 0    4.526
# 1    3.585
# 2    3.521
# 3    3.413
# 4    3.422
# Name: PRICE, dtype: float64

# %%
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X, y_reg, test_size=0.2, random_state=0)

# %%
print("\n--- 상관관계 히트맵 분석 ---")
plt.figure(figsize=(12, 8))
# 모든 수치형 데이터 간의 상관계수 계산
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', fmt='.2f')
plt.title('California Housing Correlation Heatmap')
plt.show()
# Out:
# --- 상관관계 히트맵 분석 ---

# %%
print("\n===== [Regression Results] =====")
# Linear Regression
reg_lr = LinearRegression()
reg_lr.fit(X_train_r, y_train_r)
print(f"LR MSE: {mean_squared_error(y_test_r, reg_lr.predict(X_test_r)):.4f}")

# Random Forest Regressor
reg_rf = RandomForestRegressor(random_state=0)
reg_rf.fit(X_train_r, y_train_r)
print(f"RF MSE: {mean_squared_error(y_test_r, reg_rf.predict(X_test_r)):.4f}")
# Out:
# ===== [Regression Results] =====
# LR MSE: 0.5278
