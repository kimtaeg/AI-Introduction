# %% [markdown]
# #인공지능개론 5주차 과제
#
# ###컴퓨터공학과 202337644 김태규
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# 데이터 로드
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/wine.csv')

df = df.dropna()

# 피처(X)와 타겟(y) 분리
X = df.drop('Wine', axis=1).values
y = df['Wine'].values
Y = pd.get_dummies(y).values # 클래스가 3개(0, 1, 2)이므로 원-핫 인코딩

# 데이터 분할 및 스케일링
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 모델 설계
model = Sequential([
    Dense(32, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(16, activation='relu'),
    Dense(3, activation='softmax') # 와인 종류가 3개이므로 노드 3개
])

# 컴파일 및 학습
model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=8, validation_data=(X_test, y_test))

# 결과 확인
from sklearn.metrics import classification_report
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred))
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.8099 - loss: 0.4887 - val_accuracy: 1.0000 - val_loss: 0.1031
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9789 - loss: 0.0650 - val_accuracy: 1.0000 - val_loss: 0.0165
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9930 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9930 - loss: 0.0154 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 6/50
# ...

# %%
# 피처(X)와 타겟(y) 분리
X_reg = df.drop('Wine', axis=1).values
y_reg = df['Wine'].values

# 데이터 분할 및 스케일링
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg, y_reg, test_size=0.2, random_state=0)
scaler_reg = StandardScaler()
X_train_reg = scaler_reg.fit_transform(X_train_reg)
X_test_reg = scaler_reg.transform(X_test_reg)

# 모델 설계
model_reg = Sequential([
    Dense(64, input_shape=(X_train_reg.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(1) # 수치 출력을 위해 노드 1개 (활성화 함수 없음)
])

# 컴파일 및 학습
model_reg.compile(optimizer=Adam(learning_rate=0.01), loss='mse', metrics=['mae'])
model_reg.fit(X_train_reg, y_train_reg, epochs=100, batch_size=8, validation_data=(X_test_reg, y_test_reg))

# 시각화 (예측값 vs 실제값)
y_pred_reg = model_reg.predict(X_test_reg).flatten()
plt.scatter(y_test_reg, y_pred_reg, alpha=0.6)
plt.plot([y_test_reg.min(), y_test_reg.max()], [y_test_reg.min(), y_test_reg.max()], 'r--')
plt.xlabel('Actual Alcohol')
plt.ylabel('Predicted Alcohol')
plt.title('Regression: Alcohol Prediction')
plt.show()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3624 - mae: 0.9061 - val_loss: 0.5253 - val_mae: 0.6232
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2738 - mae: 0.4186 - val_loss: 0.0914 - val_mae: 0.2198
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0949 - mae: 0.2378 - val_loss: 0.0616 - val_mae: 0.1787
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0523 - mae: 0.1747 - val_loss: 0.0880 - val_mae: 0.1872
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0493 - mae: 0.1654 - val_loss: 0.0776 - val_mae: 0.1822
# Epoch 6/100
# ...
