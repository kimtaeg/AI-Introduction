# %% [markdown]
# #인공지능개론 6주차 과제
#
# ###컴퓨터공학과 202337644 김태규
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# 데이터 로드
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/abalone.csv')
df = df.drop('id', axis=1)

df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
print("\n컬럼별 데이터 타입:")
print(df.dtypes)
print("\n기본 통계:")
print(df.describe())
print("\n결측치 확인:")
print(df.isnull().sum())
# Out:
# 컬럼별 데이터 타입:
# id                  int64
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole_weight      float64
# Shucked_weight    float64
# Viscera_weight    float64
# Shell_weight      float64
# Rings               int64
# dtype: object
#
# 기본 통계:
#                 id       Length     Diameter       Height  Whole_weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean   2088.000000     0.523992     0.407881     0.139516      0.828742
# std    1205.940366     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%    1044.000000     0.450000     0.350000     0.115000      0.441500
# 50%    2088.000000     0.545000     0.425000     0.140000      0.799500
# 75%    3132.000000     0.615000     0.480000     0.165000      1.153000
# max    4176.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked_weight  Viscera_weight  Shell_weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000
#
# 결측치 확인:
# id                0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
# X, y 분리
X = df.drop('Sex', axis=1).values # 성별 제외한 나머지 특성
y = df['Sex'].values

# %%
# 원-핫 인코딩
le = LabelEncoder()
y_encoded = le.fit_transform(y)
Y = to_categorical(y_encoded)

# 데이터 분할 및 스케일링
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# 딥러닝 모델 설계
model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(3, activation='softmax')
])

# 컴파일 및 학습
model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))


# 결과 확인
from sklearn.metrics import classification_report
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred, target_names=le.classes_))
# Out:
# Epoch 1/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.5259 - loss: 0.8873 - val_accuracy: 0.5443 - val_loss: 0.8690
# Epoch 2/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5427 - loss: 0.8560 - val_accuracy: 0.5574 - val_loss: 0.8670
# Epoch 3/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5528 - loss: 0.8504 - val_accuracy: 0.5813 - val_loss: 0.8415
# Epoch 4/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5564 - loss: 0.8434 - val_accuracy: 0.5670 - val_loss: 0.8432
# Epoch 5/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5549 - loss: 0.8442 - val_accuracy: 0.5598 - val_loss: 0.8432
# Epoch 6/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5591 - loss: 0.8369 - val_accuracy: 0.5730 - val_loss: 0.8426
# Epoch 7/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5645 - loss: 0.8418 - val_accuracy: 0.5622 - val_loss: 0.8949
# Epoch 8/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5615 - loss: 0.8375 - val_accuracy: 0.5658 - val_loss: 0.8286
# Epoch 9/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5669 - loss: 0.8366 - val_accuracy: 0.5598 - val_loss: 0.8348
# Epoch 10/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5714 - loss: 0.8339 - val_accuracy: 0.5742 - val_loss: 0.8261
# Epoch 11/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5669 - loss: 0.8334 - val_accuracy: 0.5694 - val_loss: 0.8421
# Epoch 12/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5693 - loss: 0.8352 - val_accuracy: 0.5622 - val_loss: 0.8420
# Epoch 13/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5606 - loss: 0.8274 - val_accuracy: 0.5586 - val_loss: 0.8424
# Epoch 14/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5693 - loss: 0.8252 - val_accuracy: 0.5622 - val_loss: 0.8237
# Epoch 15/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5699 - loss: 0.8235 - val_accuracy: 0.5742 - val_loss: 0.8586
# Epoch 16/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5687 - loss: 0.8262 - val_accuracy: 0.5538 - val_loss: 0.8414
# Epoch 17/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5666 - loss: 0.8221 - val_accuracy: 0.5586 - val_loss: 0.8305
# Epoch 18/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5627 - loss: 0.8270 - val_accuracy: 0.5502 - val_loss: 0.8394
# Epoch 19/50
# 105/105 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.